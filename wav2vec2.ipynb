# %%
import os
import sys
import torchaudio
import glob
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from database import Database
from dataset_preprocessor import Preprocessor, Standard_Scaler
from transformers.models.wav2vec2.feature_extraction_wav2vec2 import Wav2Vec2FeatureExtractor

# %%
base_model = "facebook/wav2vec2-xls-r-300m"
model_name = base_model.split('/')[-1]
collection = 'IEMOCAP'
# collection = 'IEMOCAP_Norm_Std'
# collection = 'IEMOCAP_Norm_MinMax'

db = Database(collection)

# %%
data = []

for path in tqdm(glob.glob("IEMOCAP_mp3/*.mp3")):
    name = str(os.path.basename(path)).split('_')[:-1]
    label = str(path).split('_')[-1].split('.')[0]
    if label == 'ang' or label == 'fru':
        label = 'positive'
    elif label == 'xxx':
        pass
    else:
        label = 'negative'
    
    try:
        # There are some broken files
        s = torchaudio.load(path)
        data.append({
            "name": name,
            "path": path,
            "emotion": label
        })
    except Exception as e:
        print(str(path), e)
# Out:
#   1%|▏         | 144/10039 [00:00<00:06, 1439.64it/s]
# IEMOCAP_mp3\Ses01F_impro01_F000_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F000_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F001_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F001_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F002_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F002_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F005_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F005_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F006_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F006_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F007_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F007_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F008_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F008_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F009_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F009_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F011_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F011_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F012_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F012_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F013_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F013_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F014_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F014_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_F015_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_F015_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M000_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M000_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M001_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M001_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M002_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M002_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M003_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M003_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M004_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M004_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M005_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M005_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M006_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M006_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M007_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M007_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M008_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M008_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M009_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M009_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M010_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M010_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M011_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M011_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro01_M013_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro01_M013_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F000_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F000_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F001_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F001_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F002_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F002_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F003_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F003_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F004_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F004_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F005_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F005_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F006_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F006_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F008_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F008_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F010_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F010_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F012_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F012_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F013_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F013_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F014_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F014_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F015_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F015_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F016_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F016_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F017_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F017_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F018_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F018_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F019_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F019_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_F020_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_F020_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M001_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M001_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M003_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M003_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M005_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M005_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M008_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M008_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M009_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M009_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M010_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M010_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M011_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M011_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M012_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M012_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M013_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M013_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M014_sad.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M014_sad.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M015_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M015_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro02_M016_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro02_M016_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F000_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F000_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F001_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F001_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F002_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F002_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F004_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F004_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F005_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F005_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F006_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F006_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F008_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F008_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F009_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F009_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F010_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F010_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F012_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F012_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F013_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F013_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F015_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F015_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F016_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F016_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F017_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F017_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F018_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F018_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F019_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F019_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F021_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F021_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F022_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F022_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F023_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F023_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F024_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F024_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F025_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F025_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_F026_hap.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_F026_hap.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_M000_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_M000_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_M001_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_M001_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_M002_sur.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_M002_sur.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03_M003_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses01F_impro03_M003_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses01F_impro03
exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_1_M030_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_1_M030_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_1_M031_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_1_M031_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_1_M032_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_1_M032_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_1_M033_exc.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_1_M033_exc.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F001_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F001_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F002_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F002_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F003_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F003_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F004_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F004_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F005_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F005_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F006_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F006_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F008_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F008_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F009_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F009_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F012_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F012_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F013_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F013_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F015_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F015_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F017_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F017_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F018_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F018_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F021_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F021_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F023_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F023_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F025_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F025_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F026_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F026_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F028_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F028_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F029_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F029_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F034_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F034_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F035_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F035_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F036_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F036_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F037_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F037_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F038_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F038_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F039_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F039_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F040_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F040_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F041_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F041_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F042_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F042_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F043_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F043_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_F044_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_F044_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M004_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M004_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M005_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M005_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M008_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M008_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M009_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M009_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M010_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M010_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M011_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M011_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M015_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M015_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M016_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M016_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M017_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M017_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M020_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M020_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M022_fru.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M022_fru.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M023_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M023_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M024_neu.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M024_neu.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M025_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M025_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M026_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M026_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M027_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M027_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M028_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M028_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M029_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M029_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M030_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M030_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M031_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M031_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M032_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M032_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M033_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M033_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M034_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M034_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M035_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M035_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M036_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M036_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M037_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M037_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M038_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M038_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M039_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M039_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M040_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M040_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M041_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M041_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M042_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M042_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M043_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M043_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M044_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M044_ang.mp3': File contains data in an unknown format.
# IEMOCAP_mp3\Ses05M_script03_2_M045_ang.mp3 Error opening 'IEMOCAP_mp3\\Ses05M_script03_2_M045_ang.mp3': File contains data in an unknown format.

# %%
df = pd.DataFrame(data)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print("Labels: ", df["emotion"].unique())
print()
df.groupby("emotion").count()[["path"]]

# %%
print(f"Step 0: {len(df)}")

df["status"] = df["path"].apply(lambda path: True if os.path.exists(path) else None)
df = df.dropna(subset=["path"])
df = df.drop("status", 1)
print(f"Step 1: {len(df)}")

df = df.sample(frac=1)
df = df.reset_index(drop=True)
df.head()

# %%
df = df.sample(frac=1)
df = df.reset_index(drop=True)
df.head()

print("Labels: ", df["emotion"].unique())
print()
df.groupby("emotion").count()[["path"]]

df["status"] = df["path"].apply(lambda path: True if os.path.exists(path) else None)
df = df.dropna(subset=["path"])
df = df.drop("status", 1)
print(f"Step 1: {len(df)}")

# %%
save_path = ".csv_files"

train_df, test_df = train_test_split(df, test_size=0.2, random_state=101, stratify=df["emotion"])
train_df = train_df.reset_index(drop=True)
test_df, val_df = train_test_split(test_df, test_size=0.5, random_state=101, stratify=test_df["emotion"])
test_df = test_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

train_df.to_csv(f"{save_path}/train.csv", sep="\t", encoding="utf-8", index=False)
test_df.to_csv(f"{save_path}/test.csv", sep="\t", encoding="utf-8", index=False)
val_df.to_csv(f"{save_path}/val.csv", sep="\t", encoding="utf-8", index=False)


print(train_df.shape)
print(test_df.shape)
print(val_df.shape)

# %%
processor = Preprocessor()
outlier_ids = list(processor.get_outliers_id(db))

train_df = train_df[~train_df['path'].isin(outlier_ids)]
test_df = test_df[~test_df['path'].isin(outlier_ids)]
val_df = val_df[~val_df['path'].isin(outlier_ids)]

train_df.to_csv(f"{save_path}/train_no_outliers_{collection}.csv", sep="\t", encoding="utf-8", index=False)
test_df.to_csv(f"{save_path}/test_no_outliers_{collection}.csv", sep="\t", encoding="utf-8", index=False)
val_df.to_csv(f"{save_path}/val_no_outliers_{collection}.csv", sep="\t", encoding="utf-8", index=False)


print(train_df.shape)
print(test_df.shape)
print(val_df.shape)

# %% [markdown]
# ## Prepare Data for Training

# %%
# Loading the created dataset using datasets
from datasets import load_dataset, load_metric
save_path = "./.csv_files"

data_files = {
    "train": f"{save_path}/train.csv", 
    "validation": f"{save_path}/test.csv",
}

dataset = load_dataset("csv", data_files=data_files, delimiter="\t", )
train_dataset = dataset["train"]
eval_dataset = dataset["validation"]

print(train_dataset)
print(eval_dataset)

# %%
# We need to specify the input and output column
input_column = "path"
output_column = "emotion"

# %%
import torch
negative_cases = train_dataset[output_column].count('negative')
positive_cases = train_dataset[output_column].count('positive')
print('Casos negativos: ',negative_cases)
print('Casos positivos: ',positive_cases)

w0 = (negative_cases + positive_cases) / (2 * negative_cases)
w1 = (positive_cases + negative_cases) / (2 * positive_cases)
class_weights = torch.tensor([w0, w1])

# Analizar este metodo: https://arxiv.org/abs/1901.05555

print('Class_weights: ', class_weights)

# %%
# we need to distinguish the unique labels in our SER dataset
label_list = train_dataset.unique(output_column)
label_list.sort()  # Let's sort it for determinism
num_labels = len(label_list)
print(f"A classification problem with {num_labels} classes: {label_list}")

# %% [markdown]
# There are three merge strategies `mean`, `sum`, and `max`

# %%
from transformers import AutoConfig, Wav2Vec2Processor

# %%
model_name_or_path = base_model
pooling_mode = "mean"

# %%
# config
config = AutoConfig.from_pretrained(
    model_name_or_path,
    num_labels=num_labels,
    label2id={label: i for i, label in enumerate(label_list)},
    id2label={i: label for i, label in enumerate(label_list)},
    finetuning_task="wav2vec2_clf",
)
setattr(config, 'pooling_mode', pooling_mode)

# %%
processor = Wav2Vec2FeatureExtractor.from_pretrained(model_name_or_path,)
target_sampling_rate = processor.sampling_rate
print(f"The target sampling rate: {target_sampling_rate}")

# %% [markdown]
# # Preprocess Data

# %%
from database import Database
from sklearn.preprocessing import MinMaxScaler
from audio_process import Filter

# %%
def speech_file_to_array_fn(path):
    speech_array, sampling_rate = torchaudio.load(path)
    resampler = torchaudio.transforms.Resample(sampling_rate, target_sampling_rate)
    speech = resampler(speech_array).squeeze().numpy()
    bandpass_filter = Filter()
    speech = bandpass_filter.process(speech, sampling_rate)
    return speech

def label_to_id(label, label_list):

    if len(label_list) > 0:
        return label_list.index(label) if label in label_list else -1

    return label
def get_features_from_db(path):
    id = 'iemocap_' +   os.path.basename(path) + '_'
    collection = db.dataset_no_aug.loc[db.dataset_no_aug['_id'] == id].drop(
            columns=["_id", "augmented", "label"]).to_numpy()
    return collection
def preprocess_function(examples):
    preprocessor = Preprocessor(scaler=Standard_Scaler())
    speech_list = [speech_file_to_array_fn(path) for path in examples[input_column]]
    feature_list = [get_features_from_db(path) for path in examples[input_column]]
    target_list = [label_to_id(label, label_list) for label in examples[output_column]]
    # feature_list = preprocessor.scale(np.array(feature_list)[:,0,:], list(target_list))
    # feature_list = MinMaxScaler().fit_transform(feature_list, target_list)
    result = processor(speech_list, sampling_rate=target_sampling_rate)
    result["labels"] = list(target_list)
    result['features'] = list(feature_list)

    return result

# %%
train_dataset = train_dataset.map(
    preprocess_function,
    batch_size=100,
    batched=True,
    num_proc=4
)
eval_dataset = eval_dataset.map(
    preprocess_function,
    batch_size=100,
    batched=True,
    num_proc=4
)

# %% [markdown]
# En caso de que se quiera entrenar con menos casos, descomentar las siguientes lineas:

# %%
# train_dataset = train_dataset.select(range(1000))

# eval_dataset = train_dataset.select(range(200))

# %% [markdown]
# ## Model
#
# Before diving into the training part, we need to build our classification model based on the merge strategy.

# %%
from dataclasses import dataclass
from typing import Optional, Tuple
import torch
from transformers.file_utils import ModelOutput


@dataclass
class SpeechClassifierOutput(ModelOutput):
    loss: Optional[torch.FloatTensor] = None
    logits: torch.FloatTensor = None
    hidden_states: Optional[Tuple[torch.FloatTensor]] = None
    attentions: Optional[Tuple[torch.FloatTensor]] = None

# %%
import torch
import torch.nn as nn
from torch.nn import BCEWithLogitsLoss, CrossEntropyLoss, MSELoss

from transformers.models.wav2vec2.modeling_wav2vec2 import (
    Wav2Vec2PreTrainedModel,
    Wav2Vec2Model
)


class Wav2Vec2ClassificationHead(nn.Module):
    """Head for wav2vec classification task."""

    def __init__(self, config):
        super().__init__()
        self.dense = nn.Linear(config.hidden_size + 57, config.hidden_size + 57)
        self.dropout = nn.Dropout(config.final_dropout)
        self.out_proj = nn.Linear(config.hidden_size + 57, config.num_labels)

    def forward(self, features, **kwargs):
        x = features
        x = self.dropout(x)
        x = self.dense(x)
        x = torch.sigmoid(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x


class Wav2Vec2ForSpeechClassification(Wav2Vec2PreTrainedModel):
    def __init__(self, config, class_weights=[1,1]):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.pooling_mode = "mean"
        self.config = config
        self.class_weights=class_weights
        self.wav2vec2 = Wav2Vec2Model(config)
        self.classifier = Wav2Vec2ClassificationHead(config)

        self.init_weights()

    def freeze_feature_extractor(self):
        self.wav2vec2.feature_extractor._freeze_parameters()

    def merged_strategy(
            self,
            hidden_states,
            mode="mean"
    ):
        if mode == "mean":
            outputs = torch.mean(hidden_states, dim=1)
        elif mode == "sum":
            outputs = torch.sum(hidden_states, dim=1)
        elif mode == "max":
            outputs = torch.max(hidden_states, dim=1)[0]
        else:
            raise Exception(
                "The pooling method hasn't been defined! Your pooling mode must be one of these ['mean', 'sum', 'max']")

        return outputs

    def forward(
            self,
            input_values,
            features,
            attention_mask=None,
            output_attentions=None,
            output_hidden_states=None,
            return_dict=None,
            labels=None,
    ):
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict
        outputs = self.wav2vec2(
            input_values,
            attention_mask=attention_mask,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )
        hidden_states = outputs[0]
        hidden_states = self.merged_strategy(hidden_states, mode=self.pooling_mode)
        
        features = torch.tensor(features)
        size = features.size()
        features = torch.reshape(features, (size[0], size[-1]))
        features = torch.cat([hidden_states, features], 1)
        logits = self.classifier(features)

        loss = None
        if labels is not None:
            if self.config.problem_type is None:
                if self.num_labels == 1:
                    self.config.problem_type = "regression"
                elif self.num_labels > 1 and (labels.dtype == torch.long or labels.dtype == torch.int):
                    self.config.problem_type = "single_label_classification"
                else:
                    self.config.problem_type = "multi_label_classification"

            if self.config.problem_type == "regression":
                loss_fct = MSELoss()
                loss = loss_fct(logits.view(-1, self.num_labels), labels)
            elif self.config.problem_type == "single_label_classification":
                loss_fct = CrossEntropyLoss(weight=self.class_weights)
                loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
            elif self.config.problem_type == "multi_label_classification":
                loss_fct = BCEWithLogitsLoss()
                loss = loss_fct(logits, labels)

        if not return_dict:
            output = (logits,) + outputs[2:]
            return ((loss,) + output) if loss is not None else output

        return SpeechClassifierOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions,
        )

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).

# %%
from dataclasses import dataclass
from typing import Dict, List, Optional, Union
import torch

import transformers
from transformers import Wav2Vec2Processor


@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [feature["labels"] for feature in features]
        acoustic_features = [feature['features'] for feature in features]
        d_type = torch.long if isinstance(label_features[0], int) else torch.float

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )

        batch["labels"] = torch.tensor(label_features, dtype=d_type)
        batch["features"] = torch.tensor(acoustic_features)
        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. There are many pre-defined metrics for classification/regression problems, but in this case, we would continue with just **Accuracy** for classification and **MSE** for regression. You can define other metrics on your own.

# %%
is_regression = False

# %%
import numpy as np
from transformers import EvalPrediction
from evaluator import Evaluator


def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.squeeze(preds) if is_regression else np.argmax(preds, axis=1)

    if is_regression:
        return {"mse": ((preds - p.label_ids) ** 2).mean().item()}
    else:
        # evaluator = Evaluator()
        # metrics = Evaluator.evaluate_from_pred(p.label_ids, preds)
        # r = {'recall':metrics.recall}
        # return r
        return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}

# %% [markdown]
# Now, we can load the pretrained XLSR-Wav2Vec2 checkpoint into our classification model with a pooling strategy.

# %%
model = Wav2Vec2ForSpeechClassification.from_pretrained(
    model_name_or_path,
    config=config,
    class_weights=class_weights,
)

# %% [markdown]
# The first component of XLSR-Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretraining and as stated in the [paper](https://arxiv.org/pdf/2006.13979.pdf) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_extractor()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Common Voice dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# **Note**: If one wants to save the trained models in his/her google drive the commented-out `output_dir` can be used instead.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir=model_name,
    # output_dir="/content/gdrive/MyDrive/wav2vec2-xlsr-greek-speech-emotion-recognition"
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=2,
    evaluation_strategy="steps",
    num_train_epochs=1.0,
    # fp16=True,
    save_steps=10,
    eval_steps=10,
    logging_steps=10,
    learning_rate=1e-4,
    save_total_limit=2,
)

# %% [markdown]
# For future use we can create our training script, we do it in a simple way. You can add more on you own.

# %%
from typing import Any, Dict, Union
from transformers.trainer_callback import TrainerCallback
import torch
from packaging import version
from torch import nn
from transformers.data.data_collator import DataCollator
from typing import Callable
from transformers import (
    Trainer,
    is_apex_available,
)
from transformers.modeling_utils import PreTrainedModel
from torch.utils.data import Dataset
from transformers.tokenization_utils_base import PreTrainedTokenizerBase
if is_apex_available():
    from apex import amp

if version.parse(torch.__version__) >= version.parse("1.6"):
    _is_native_amp_available = True
    from torch.cuda.amp import autocast


class CTCTrainer(Trainer):
    def __init__(
        self,
        model: Union[PreTrainedModel, nn.Module] = None,
        args: TrainingArguments = None,
        data_collator: Optional[DataCollator] = None,
        train_dataset: Optional[Dataset] = None,
        eval_dataset: Optional[Dataset] = None,
        tokenizer: Optional[PreTrainedTokenizerBase] = None,
        model_init: Callable[[], PreTrainedModel] = None,
        compute_metrics: Optional[Callable[[EvalPrediction], Dict]] = None,
        callbacks: Optional[List[TrainerCallback]] = None,
        optimizers: Tuple[torch.optim.Optimizer, torch.optim.lr_scheduler.LambdaLR] = (None, None),
        class_weights: list = None
    ):

        self.class_weights = class_weights
        super().__init__(
            model = model,
            args = args,
            data_collator = data_collator,
            train_dataset = train_dataset,
            eval_dataset = eval_dataset,
            tokenizer = tokenizer,
            model_init = model_init,
            compute_metrics = compute_metrics,
            callbacks = callbacks,
            optimizers = optimizers
            )

    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs.get("labels")
        # forward pass
        outputs = model(**inputs)
        logits = outputs.get('logits')
        # compute custom loss
        loss_fct = CrossEntropyLoss(weight=self.class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))

        return (loss, outputs) if return_outputs else loss
    def training_step(self, model: nn.Module, inputs: Dict[str, Union[torch.Tensor, Any]]) -> torch.Tensor:
        """
        Perform a training step on a batch of inputs.

        Subclass and override to inject custom behavior.

        Args:
            model (:obj:`nn.Module`):
                The model to train.
            inputs (:obj:`Dict[str, Union[torch.Tensor, Any]]`):
                The inputs and targets of the model.

                The dictionary will be unpacked before being fed to the model. Most models expect the targets under the
                argument :obj:`labels`. Check your model's documentation for all accepted arguments.

        Return:
            :obj:`torch.Tensor`: The tensor with training loss on this batch.
        """

        model.train()
        inputs = self._prepare_inputs(inputs)

        if self.use_amp:
            with autocast():
                loss = self.compute_loss(model, inputs)
        else:
            loss = self.compute_loss(model, inputs)

        if self.args.gradient_accumulation_steps > 1:
            loss = loss / self.args.gradient_accumulation_steps

        if self.use_amp:
            self.scaler.scale(loss).backward()
        elif self.use_apex:
            with amp.scale_loss(loss, self.optimizer) as scaled_loss:
                scaled_loss.backward()
        elif self.deepspeed:
            self.deepspeed.backward(loss)
        else:
            loss.backward()

        return loss.detach()

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
trainer = CTCTrainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=min_train_dataset,
    eval_dataset=min_eval_dataset,
    tokenizer=processor,
    class_weights=class_weights,
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device == 'cpu':
    import multiprocessing
    ncpus = multiprocessing.cpu_count()
    torch.set_num_threads(ncpus)

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take between 10 and 60 minutes depending on the GPU allocated to this notebook.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (right mouse click -> inspect -> Console tab and insert code).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %%
trainer.train()

# %% [markdown]
# The training loss goes down and we can see that the Acurracy on the test set also improves nicely. Because this notebook is just for demonstration purposes, we can stop here.
#
# The resulting model of this notebook has been saved to [m3hrdadfi/wav2vec2-xlsr-greek-speech-emotion-recognition](https://huggingface.co/m3hrdadfi/wav2vec2-xlsr-greek-speech-emotion-recognition)
#
# As a final check, let's load the model and verify that it indeed has learned to recognize the emotion in the speech.
#
# Let's first load the pretrained checkpoint.

# %% [markdown]
# ## Evaluation

# %%
import librosa
from sklearn.metrics import classification_report

# %%
test_dataset = load_dataset("csv", data_files={"test": "./test.csv"}, delimiter="\t")["test"]
test_dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# %%
n_checkpoint = 0
checkpoints = glob.glob(f'{model_name}checkpoint-*')
for checkpoint in checkpoints:
    n = int(checkpoint.split('-')[-1])
    if n > n_checkpoint:
        n_checkpoint = n
    
model_name_or_path = f"{model_name}/checkpoint-{n_checkpoint}"

# %%
config = AutoConfig.from_pretrained(model_name_or_path)
setattr(config, 'pooling_mode', pooling_mode)
processor = Wav2Vec2FeatureExtractor.from_pretrained(model_name_or_path,)
model = Wav2Vec2ForSpeechClassification.from_pretrained(model_name_or_path).to(device)

# %%
def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    speech_array = speech_array.squeeze().numpy()
    speech_array = librosa.resample(np.asarray(speech_array), sampling_rate, processor.sampling_rate)

    batch["speech"] = speech_array
    id = 'iemocap_' +   os.path.basename(batch["path"]) + '_'
    collection = db.dataset_no_aug.loc[db.dataset_no_aug['_id'] == id].drop(
            columns=["_id", "augmented", "label"]).to_numpy()
    batch["features"] = collection
    return batch


def predict(batch):
    features = processor(batch["speech"], sampling_rate=processor.sampling_rate, return_tensors="pt", padding=True)
    acoustic_features = batch["features"]
    input_values = features.input_values.to(device)
    # attention_mask = features.attention_mask.to(device)

    with torch.no_grad():
        logits = model(input_values, features=acoustic_features).logits 

    pred_ids = torch.argmax(logits, dim=-1).detach().cpu().numpy()
    batch["predicted"] = pred_ids
    return batch

# %%
test_dataset = test_dataset.map(speech_file_to_array_fn)

# %%
result = test_dataset.map(predict, batched=True, batch_size=8)

# %%
label_names = [config.id2label[i] for i in range(config.num_labels)]
label_names

# %%
y_true = [0 if name=='negative' else 1 for name in result["emotion"]]
y_pred = result["predicted"]

print(y_true[:5])
print(y_pred[:5])

# %%
print(classification_report(y_true, y_pred, target_names=label_names))

# %% [markdown]
# ## Prediction (no probado)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
from transformers import AutoConfig, Wav2Vec2Processor

import librosa
import IPython.display as ipd
import numpy as np
import pandas as pd

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_name_or_path = "facebook/wav2vec2-base-960h"
config = AutoConfig.from_pretrained(model_name_or_path)
processor = Wav2Vec2Processor.from_pretrained(model_name_or_path)
sampling_rate = processor.feature_extractor.sampling_rate
model = Wav2Vec2ForSpeechClassification.from_pretrained(model_name_or_path).to(device)

# %%
def speech_file_to_array_fn(path, sampling_rate):
    speech_array, _sampling_rate = torchaudio.load(path)
    resampler = torchaudio.transforms.Resample(_sampling_rate)
    speech = resampler(speech_array).squeeze().numpy()
    return speech


def predict(path, sampling_rate):
    speech = speech_file_to_array_fn(path, sampling_rate)
    features = processor(speech, sampling_rate=sampling_rate, return_tensors="pt", padding=True)

    input_values = features.input_values.to(device)
    attention_mask = features.attention_mask.to(device)

    with torch.no_grad():
        logits = model(input_values, attention_mask=attention_mask).logits

    scores = F.softmax(logits, dim=1).detach().cpu().numpy()[0]
    outputs = [{"Emotion": config.id2label[i], "Score": f"{round(score * 100, 3):.1f}%"} for i, score in enumerate(scores)]
    return outputs


STYLES = """
<style>
div.display_data {
    margin: 0 auto;
    max-width: 500px;
}
table.xxx {
    margin: 50px !important;
    float: right !important;
    clear: both !important;
}
table.xxx td {
    min-width: 300px !important;
    text-align: center !important;
}
</style>
""".strip()

def prediction(df_row):
    path, emotion = df_row["path"], df_row["emotion"]
    df = pd.DataFrame([{"Emotion": emotion, "Sentence": "    "}])
    setup = {
        'border': 2,
        'show_dimensions': True,
        'justify': 'center',
        'classes': 'xxx',
        'escape': False,
    }
    ipd.display(ipd.HTML(STYLES + df.to_html(**setup) + "<br />"))
    speech, sr = torchaudio.load(path)
    speech = speech[0].numpy().squeeze()
    speech = librosa.resample(np.asarray(speech), sr, sampling_rate)
    ipd.display(ipd.Audio(data=np.asarray(speech), autoplay=True, rate=sampling_rate))

    outputs = predict(path, sampling_rate)
    r = pd.DataFrame(outputs)
    ipd.display(ipd.HTML(STYLES + r.to_html(**setup) + "<br />"))

# %%
test = pd.read_csv("/content/data/test.csv", sep="\t")
test.head()

# %%
prediction(test.iloc[0])

# %%
prediction(test.iloc[1])

# %%
prediction(test.iloc[2])
